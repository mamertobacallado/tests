# %% [markdown]
# # Esto es un ejemplo de notebook

# %% [markdown]
# Voy a hacer un dibujo simple en Python.
#
# Empiezo por cargar las extensiones necesarias:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# A continuación genero algunos datos

# %%
x     = np.arange(0,100,step=1)
sigma = 20.0
y     = np.exp(-(x-50)**2/sigma**2)

# %% [markdown]
# Y los represento:

# %%
fig,ax = plt.subplots()
ax.plot(x,y)
ax.grid()

# %% [markdown]
# Más información sobre la extensión Matplotlib en [este enlace](https://matplotlib.org/)
